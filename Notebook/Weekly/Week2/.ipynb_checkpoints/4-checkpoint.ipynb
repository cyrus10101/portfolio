# %%
#4
weets = int(input("Insert sweets: "))
pupils = int(input("Insert pupils: "))

per_pupil = sweets // pupils
leftover = sweets % pupils

print(f"Each pupil gets {per_pupil} sweets.")
print(f"Sweets left over: {leftover}")
