# %%
#8
import statistics 

temperatures = []

while(True):
    i = 1 
    user_input = input(f'Enter temperature {i + 1} in Celsius: ')

    if user_input.strip() == '':
        break

    temp = float(user_input)
    temperatures.append(temp)
    i += 1
    []
maximun = max(temperatures)
minimun = min(temperatures)
mean = statistics.mean(temperatures)

print(f'Maximum temperature: {maximun}C')
print(f'Minimum temperature: {minimun}C')
print(f'Mean temperature: {mean}C')
# Out:
# Enter temperature 2 in Celsius:  23
# Enter temperature 2 in Celsius:  24
# Enter temperature 2 in Celsius:  25
# Enter temperature 2 in Celsius:  26
# Enter temperature 2 in Celsius:
# Maximum temperature: 26.0C
# Minimum temperature: 23.0C
# Mean temperature: 24.5C
