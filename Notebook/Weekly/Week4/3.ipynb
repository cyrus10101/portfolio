# %%
#3
name = input("Hello, What is your name?: ")
if name.strip() == "":
    print("Hello, Stranger! Good to meet you!")
else:
    name_formatted = name.strip().capitalize()
    print(f'Hello, {name_formatted}. Good to meet you!')
# Out:
# Hello, What is your name?:  cyrus
# Hello, Cyrus. Good to meet you!
