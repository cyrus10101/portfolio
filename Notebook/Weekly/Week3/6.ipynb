# %%
#6
for i in range(0, 13):
    print(f"{i} * {7} = {i * 7}")
# Out:
# 0 * 7 = 0
# 1 * 7 = 7
# 2 * 7 = 14
# 3 * 7 = 21
# 4 * 7 = 28
# 5 * 7 = 35
# 6 * 7 = 42
# 7 * 7 = 49
# 8 * 7 = 56
# 9 * 7 = 63
# 10 * 7 = 70
# 11 * 7 = 77
# 12 * 7 = 84
