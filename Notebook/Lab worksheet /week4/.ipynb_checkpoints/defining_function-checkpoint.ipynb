# %%
def multiply(a, b=None):
    if b is None:
        b = a
    return a * b

print("multiply(5, 3) =", multiply(5, 3)) 
print("multiply(4) =", multiply(4))       
print("multiply(7, 2) =", multiply(7, 2))  
print("multiply(9) =", multiply(9))        

def someFunc(x, y, z):
    print("x is", x)
    print("y is", y)
    print("z is", z)

someFunc(y=2, z=3, x=1)
someFunc(z=99, y=4, x=10)
someFunc(5, z=7, y=6)  

def showMsg(title, body="", prefix="INFO", suffix="."):
    print(prefix, title, body, suffix)


showMsg("File opened")
showMsg("File not opened", prefix="ERROR")
showMsg("File missing", body="Insert Disk", suffix="Press return")

print("Apple", "Banana", "Cherry", sep=", ")
print("2025", "12", "10", sep="-")
print("A", "B", "C", sep=" | ")

def calcAve(*numbers):
    total = 0
    for num in numbers:
        total += num
    return total / len(numbers)

print("Average of 1, 2, 3 =", calcAve(1, 2, 3))
print("Average of 12, 26 =", calcAve(12, 26))
print("Average of 9, 4, 3, 6, 5 =", calcAve(9, 4, 3, 6, 5))
# Out:
# multiply(5, 3) = 15
# multiply(4) = 16
# multiply(7, 2) = 14
# multiply(9) = 81
# x is 1
# y is 2
# z is 3
# x is 10
# y is 4
# z is 99
# x is 5
# y is 6
# z is 7
# INFO File opened  .
# ERROR File not opened  .
# INFO File missing Insert Disk Press return
# Apple, Banana, Cherry
# 2025-12-10
# A | B | C
# Average of 1, 2, 3 = 2.0
# Average of 12, 26 = 19.0
# Average of 9, 4, 3, 6, 5 = 5.4
