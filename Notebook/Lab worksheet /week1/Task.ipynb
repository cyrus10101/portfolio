# %%
# --- TASK: First Program Run ---
print("the program has executed")

# --- TASK: Printing Different Messages ---
print("This is the second message")
print("Python programming is interesting")
print("I am completing my FOCP assignment")

# --- TASK: Recalling Previous Commands ---
# Just showing how we can reuse commands (simulated here)
print("This is the second message")

# --- TASK: Using Help Function ---
# help() is commented out so the program doesn't pause
# help()
# help(print)
# help(input)
print("Checked help commands manually.")

# --- TASK: Trying Simple Calculations ---
print("45 + 20 =", 45 + 20)

# --- TASK: Using Basic Operators ---
print("10 + 20 - 15 =", 10 + 20 - 15)
print("10 * 5 =", 10 * 5)
print("100 / 33 =", 100 / 33)       # Normal division
print("100 // 33 =", 100 // 33)     # Division without remainder
print("10 ** 2 =", 10 ** 2)         # Exponent (power)
print("10 % 3 =", 10 % 3)           # Remainder after division

# --- TASK: Operator Precedence Examples ---
print("10 + 5 * 2 =", 10 + 5 * 2)
print("10 - 5 * 10 + 5 =", 10 - 5 * 10 + 5)
print("5 * 10 ** 2 =", 5 * 10 ** 2)

# --- TASK: Using Parentheses to Change Order ---
print("(10 + 5) * 2 =", (10 + 5) * 2)
print("10 - 5 * (10 + 5) =", 10 - 5 * (10 + 5))
print("(5 * 10) ** 2 =", (5 * 10) ** 2)

# --- TASK: Nested Parentheses ---
print("12 + (5 * 2 + 3) =", 12 + (5 * 2 + 3))
print("12 + (5 * (2 + 3)) =", 12 + (5 * (2 + 3)))

# --- TASK: Handling Errors ---
# Syntax error example (commented so program still runs)
# 10 +  

# Runtime error example: division by zero
# We use try-except to catch the error and keep the program running
try:
    print("Ten divided by zero is", 10/0)
except ZeroDivisionError as e:
    print("Error occurred:", e)

# --- TASK: Key Terms in Programming ---
print("\n--- Key Programming Terms ---")
print("Source code: The code we write in a human-readable form.")
print("Machine code: Binary instructions the computer executes (0s and 1s).")
print("Interpreter: Runs code line by line (like Python).")
print("Compiler: Converts all code to a file before running.")
print("Executable: A file that can be run on the computer (e.g., .exe).")
print("Expressions: Combinations of values and operators that produce a result.")
print("Operators: Symbols that do math or logic (+, -, *, /, etc.).")
print("Operands: The values or variables operators act on.")
print("Syntax Errors: Mistakes in code grammar that prevent it from running.")
print("Logical Errors: Mistakes in logic that produce wrong results or crashes.")

# --- TASK: Ending the Program ---
print("\nEnd of assignment tasks.")
quit()
# Out:
# the program has executed
# This is the second message
# Python programming is interesting
# I am completing my FOCP assignment
# This is the second message
# Checked help commands manually.
# 45 + 20 = 65
# 10 + 20 - 15 = 15
# 10 * 5 = 50
# 100 / 33 = 3.0303030303030303
# 100 // 33 = 3
# 10 ** 2 = 100
# 10 % 3 = 1
# 10 + 5 * 2 = 20
# 10 - 5 * 10 + 5 = -35
# 5 * 10 ** 2 = 500
# (10 + 5) * 2 = 30
# 10 - 5 * (10 + 5) = -65
# (5 * 10) ** 2 = 2500
# 12 + (5 * 2 + 3) = 25
# 12 + (5 * (2 + 3)) = 37
# Error occurred: division by zero
#
# --- Key Programming Terms ---
# Source code: The code we write in a human-readable form.
# Machine code: Binary instructions the computer executes (0s and 1s).
# Interpreter: Runs code line by line (like Python).
# Compiler: Converts all code to a file before running.
# Executable: A file that can be run on the computer (e.g., .exe).
# Expressions: Combinations of values and operators that produce a result.
# ...
